# %%
import sys
sys.path
# Out:
# ['/Users/gonakazawa/Documents/go/dev_environments/bayes_optimization',
#  '/opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python310.zip',
#  '/opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10',
#  '/opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/lib-dynload',
#  '',
#  '/opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages',
#  '/opt/homebrew/opt/six/lib/python3.10/site-packages',
#  '/opt/homebrew/lib/python3.10/site-packages']

# %%
sys.path.append("/Users/gonakazawa/.pyenv/versions/3.10.6/lib/python3.10/site-packages")

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.2.1-cp310-cp310-macosx_12_0_arm64.whl (8.4 MB)
# Collecting joblib>=1.1.1
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: scipy>=1.3.2 in /Users/gonakazawa/.pyenv/versions/3.10.6/lib/python3.10/site-packages (from scikit-learn) (1.10.0)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.17.3 in /Users/gonakazawa/.pyenv/versions/3.10.6/lib/python3.10/site-packages (from scikit-learn) (1.23.3)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.1 threadpoolctl-3.1.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import datetime as dt
data = pd.DataFrame()

# %%
# !ls
# Out:
# data                                    marodata_linear_reggression.ipynb
# imgs                                    note01_regression.ipynb
# maro_cagedata.csv                       note02_optimization.ipynb
# maro_cagedataの元データ.csv             note03_experimental_design.ipynb
# maro_data_2.csv                         note04_batchBO.ipynb
# marodata_linear_reggression-Copy1.ipynb ベイズ最適化.pdf

# %%
maro = pd.read_csv('maro_data_2.csv')
maro
# Out:
#                 Date  temperature  humidity
# 0   2023-01-20 01:43         21.0        74
# 1   2023-01-21 01:43         21.4        65
# 2   2023-01-22 01:43         20.2        71
# 3   2023-01-23 01:43         22.2        71
# 4   2023-01-24 01:43         22.6        71
# 5   2023-01-25 01:43         22.5        61
# 6   2023-01-26 01:43         22.4        64
# 7   2023-01-27 01:43         21.2        63
# 8   2023-01-28 01:43         23.3        60
# 9   2023-01-29 01:43         20.5        65
# 10  2023-01-30 01:43         21.4        63
# 11  2023-01-31 01:43         21.5        62
# 12  2023-02-01 01:43         21.7        63
# 13  2023-02-02 01:43         22.2        62
# 14  2023-02-03 01:43         22.9        62
# 15  2023-02-04 01:43         22.1        62
# 16  2023-02-05 01:43         22.5        65
# 17  2023-02-06 01:43         21.2        72
# 18  2023-02-07 01:43         22.6        64
# 19  2023-02-08 01:43         21.7        67
# 20  2023-02-09 01:43         22.6        72
# 21  2023-02-10 01:43         23.3        68
# 22  2023-02-11 01:43         23.5        61
# 23  2023-02-12 01:43         22.0        73
# 24  2023-02-13 01:43         22.4        65
# 25  2023-02-14 01:43         21.5        76
# 26  2023-02-15 01:43         23.4        61
# 27  2023-02-16 01:43         21.6        70
# 28  2023-02-17 01:43         22.1        67
# 29  2023-02-18 01:43         23.2        64
# 30  2023-02-19 01:43         22.9        65
# 31  2023-02-20 01:43         22.6        66
# 32  2023-02-21 01:43         23.9        58
# 33  2023-02-22 01:43         22.6        66
# 34  2023-02-23 01:43         23.5        58
# 35  2023-02-24 01:43         23.8        57

# %%
df = pd.DataFrame(maro)
df.head()
# Out:
#                Date  temperature  humidity
# 0  2023-01-20 01:43         21.0        74
# 1  2023-01-21 01:43         21.4        65
# 2  2023-01-22 01:43         20.2        71
# 3  2023-01-23 01:43         22.2        71
# 4  2023-01-24 01:43         22.6        71

# %%
df["year"] = df['Date'].str[:4]
df["month"] = df['Date'].str[5:7]
df["day"] = df['Date'].str[8:10]
df["time"] = df['Date'].str[11:13]
df
# Out:
#                 Date  temperature  humidity  year month day time
# 0   2023-01-20 01:43         21.0        74  2023    01  20   01
# 13  2023-02-02 01:43         22.2        62  2023    02  02   01  2023020201
# 14  2023-02-03 01:43         22.9        62  2023    02  03   01  2023020301
# 15  2023-02-04 01:43         22.1        62  2023    02  04   01  2023020401
# 16  2023-02-05 01:43         22.5        65  2023    02  05   01  2023020501
# 17  2023-02-06 01:43         21.2        72  2023    02  06   01  2023020601
# 18  2023-02-07 01:43         22.6        64  2023    02  07   01  2023020701
# 19  2023-02-08 01:43         21.7        67  2023    02  08   01  2023020801
# 20  2023-02-09 01:43         22.6        72  2023    02  09   01  2023020901
# 21  2023-02-10 01:43         23.3        68  2023    02  10   01  2023021001
# 22  2023-02-11 01:43         23.5        61  2023    02  11   01  2023021101
# 23  2023-02-12 01:43         22.0        73  2023    02  12   01  2023021201
# 24  2023-02-13 01:43         22.4        65  2023    02  13   01  2023021301
# 25  2023-02-14 01:43         21.5        76  2023    02  14   01  2023021401
# 26  2023-02-15 01:43         23.4        61  2023    02  15   01  2023021501
# 27  2023-02-16 01:43         21.6        70  2023    02  16   01  2023021601
# 28  2023-02-17 01:43         22.1        67  2023    02  17   01  2023021701
# 29  2023-02-18 01:43         23.2        64  2023    02  18   01  2023021801
# 30  2023-02-19 01:43         22.9        65  2023    02  19   01  2023021901
# 31  2023-02-20 01:43         22.6        66  2023    02  20   01  2023022001
# 32  2023-02-21 01:43         23.9        58  2023    02  21   01  2023022101
# 33  2023-02-22 01:43         22.6        66  2023    02  22   01  2023022201
# 34  2023-02-23 01:43         23.5        58  2023    02  23   01  2023022301
# 35  2023-02-24 01:43         23.8        57  2023    02  24   01  2023022401

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.1-cp310-cp310-macosx_12_0_arm64.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 13.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting scipy>=1.3.2
#   Downloading scipy-1.10.1-cp310-cp310-macosx_12_0_arm64.whl (28.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 21.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting numpy>=1.17.3
#   Downloading numpy-1.24.2-cp310-cp310-macosx_11_0_arm64.whl (13.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 12.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit-learn
# Successfully installed joblib-1.2.0 numpy-1.24.2 scikit-learn-1.2.1 scipy-1.10.1 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

X1 = maro[['new_date']].values         # 説明変数（Numpyの配列）
Y = maro[['temperature']].values         # 目的変数（Numpyの配列）

lr.fit(X1, Y)                        # 線形モデルの重みを学習
# Out:
# LinearRegression()

# %%
print('coefficient = ', lr.coef_[0]) # 説明変数の係数を出力
print('intercept = ', lr.intercept_) # 切片を出力
# Out:
# coefficient =  [0.00011094]
# intercept =  [-224408.62053593]

# %%
plt.scatter(X1, Y, color = 'blue')         # 説明変数と目的変数のデータ点の散布図をプロット
plt.plot(X1, lr.predict(X1), color = 'red') # 回帰直線をプロット

plt.title('Regression Line')               # 図のタイトル
plt.xlabel('jan_to_feb') # x軸のラベル
plt.ylabel('cage_temp')    # y軸のラベル
plt.grid()                                 # グリッド線を表示

plt.show()                                 # 図の表示

# %%
plt.hist(df['temperature'])
# Out:
# (array([  5.,  14.,  31.,  61.,  89., 167., 212., 150., 104.,  40.]),
#  array([18.8 , 19.34, 19.88, 20.42, 20.96, 21.5 , 22.04, 22.58, 23.12,
#         23.66, 24.2 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Scikit-learn で線形回帰
# https://qiita.com/0NE_shoT_/items/08376b08783cd554b02e
#
# 【Python】日付型データから年・月・日を取り出す方法｜datetime
# https://smart-hint.com/python/datetime-ymd/
#
# pandasで文字列にスライスを適用して任意の位置・長さの部分を抽出
# https://note.nkmk.me/python-pandas-str-combine/
#
# pandas.DataFrameの複数の列の文字列を結合して新たな列を生成
# https://note.nkmk.me/python-pandas-str-combine/
